# %% [markdown]
# <a href="https://colab.research.google.com/github/matyi101/price_catcher/blob/main/price_catcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
path = "/content/drive/MyDrive/Colab Notebooks/price_catcher/"

from google.colab import data_table
data_table.enable_dataframe_formatter()
# Out:
# Mounted at /content/drive/

# %%
import os
import pandas as pd
import glob

import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams["figure.figsize"] = (8,4)
plt.rcParams["figure.dpi"] = 160
plt.rcParams["axes.grid"] = True

# %%
premise = pd.read_csv('https://storage.googleapis.com/dosm-public-pricecatcher/lookup_premise.csv')
premise = premise.dropna()
premise.head()
# Out:
#    premise_code                            premise  \
# 1             2                   PASAR BESAR IPOH
# 2             3                   JUSCO AYER KEROH
# 3             6  KEDAI RUNCIT TAFAZ MAJU PRESINT 9
# 4             7   KEDAI RUNCIT SYAZ MAJU PRESINT 9
# 5             8        PASAR MINI D'MART PRESINT 8
#
#                                              address  \
# 1    JALAN LAKSAMANA,TAMAN JUBILEE,30300 IPOH, PERAK
# 2  LOT 4991,MUKIM BUKIT BARU,75450 LEBUH AYER KER...
# 3        NO.5, JALAN P9B/1,PRESINT 9,62250 PUTRAJAYA
# 4        NO.5, JALAN P9E/1,PRESINT 9,62250 PUTRAJAYA
# 5  BLOK A T00/U01,JALAN P8/D,PRESINT 8, 62000 PUT...
#
#                premise_type           state       district
# 1              Pasar Basah            Perak          Kinta
# 2  Pasar Raya / Supermarket          Melaka  Melaka Tengah
# 3              Kedai Runcit  W.P. Putrajaya   Wp Putrajaya
# 4              Kedai Runcit  W.P. Putrajaya   Wp Putrajaya
# 5                Pasar Mini  W.P. Putrajaya   Wp Putrajaya

# %%
items = pd.read_csv('https://storage.googleapis.com/dosm-public-pricecatcher/lookup_item.csv')
items = items.dropna()
items.head()
# Out:
#    item_code                                               item unit  \
# 1          1                             AYAM BERSIH - STANDARD  1kg
# 2          2                                AYAM BERSIH - SUPER  1kg
# 3          3                                         AYAM HIDUP  1kg
# 4          9  DAGING KAMBING BEBIRI IMPORT BERTULANG (MUTTON...  1kg
# 5         10  DAGING KAMBING BEBIRI IMPORT BERTULANG (MUTTON...  1kg
#
#        item_group item_category
# 1  BARANGAN SEGAR          AYAM
# 2  BARANGAN SEGAR          AYAM
# 3  BARANGAN SEGAR          AYAM
# 4  BARANGAN SEGAR        DAGING
# 5  BARANGAN SEGAR        DAGING

# %%
# Define the directory path where the data are located
directory_path = "/content/drive/MyDrive/Colab Notebooks/price_catcher/data/"

# Use glob to get a list of file names that match a pattern
file_names = glob.glob(directory_path + "*.csv")

# Create an empty list to store the data frames
data_frames = []

# Loop through the file names and read each file as a data frame
for file in file_names:
    # Read the file using pandas read_csv function
    df = pd.read_csv(file)
    # Append the data frame to the list
    data_frames.append(df)

# Use pandas concat function to combine the data frames into one
df = pd.concat(data_frames, ignore_index=True)
df.head()
# Out:
#          date  premise_code  item_code  price
# 0  2023-01-01             2          1    9.4
# 1  2023-01-01             2          9   36.0
# 2  2023-01-01             2         14   24.0
# 3  2023-01-01             2         16    4.5
# 4  2023-01-01             2         18    5.5

# %%
combine = df.merge(premise, on="premise_code", how="left")
combine.head()
# Out:
#          date  premise_code  item_code  price           premise  \
# 0  2023-01-01             2          1    9.4  PASAR BESAR IPOH
# 1  2023-01-01             2          9   36.0  PASAR BESAR IPOH
# 2  2023-01-01             2         14   24.0  PASAR BESAR IPOH
# 3  2023-01-01             2         16    4.5  PASAR BESAR IPOH
# 4  2023-01-01             2         18    5.5  PASAR BESAR IPOH
#
#                                            address  premise_type  state  \
# 0  JALAN LAKSAMANA,TAMAN JUBILEE,30300 IPOH, PERAK  Pasar Basah   Perak
# 1  JALAN LAKSAMANA,TAMAN JUBILEE,30300 IPOH, PERAK  Pasar Basah   Perak
# 2  JALAN LAKSAMANA,TAMAN JUBILEE,30300 IPOH, PERAK  Pasar Basah   Perak
# 3  JALAN LAKSAMANA,TAMAN JUBILEE,30300 IPOH, PERAK  Pasar Basah   Perak
# 4  JALAN LAKSAMANA,TAMAN JUBILEE,30300 IPOH, PERAK  Pasar Basah   Perak
#
#   district
# 0    Kinta
# 1    Kinta
# 2    Kinta
# 3    Kinta
# 4    Kinta

# %%
df_combine = combine.merge(items, on="item_code", how="left")
df_combine
# Out:
# Warning: total number of rows (14565774) exceeds max_rows (20000). Falling back to pandas display.
#                 date  premise_code  item_code  price  \
# 0         2023-01-01             2          1   9.40
# 1         2023-01-01             2          9  36.00
# 2         2023-01-01             2         14  24.00
# 3         2023-01-01             2         16   4.50
# 4         2023-01-01             2         18   5.50
# ...              ...           ...        ...    ...
# 14565769  2023-07-06         20888       1938  13.30
# 14565770  2023-07-06         20888       1939  30.90
# 14565771  2023-07-06         20888       1941  13.30
# 14565772  2023-07-06         20888       1944   5.99
# 14565773  2023-07-06         20888       1946   1.10
#
#                             premise  \
# 0                  PASAR BESAR IPOH
# 1                  PASAR BESAR IPOH
# 2                  PASAR BESAR IPOH
# 3                  PASAR BESAR IPOH
# 4                  PASAR BESAR IPOH
# ...                             ...
# 14565769  BS FRESHMART MUADZAM SHAH
# 14565770  BS FRESHMART MUADZAM SHAH
# 14565771  BS FRESHMART MUADZAM SHAH
# 14565772  BS FRESHMART MUADZAM SHAH
# 14565773  BS FRESHMART MUADZAM SHAH
#
#                                                   address  \
# 0         JALAN LAKSAMANA,TAMAN JUBILEE,30300 IPOH, PERAK
# 1         JALAN LAKSAMANA,TAMAN JUBILEE,30300 IPOH, PERAK
# 2         JALAN LAKSAMANA,TAMAN JUBILEE,30300 IPOH, PERAK
# 3         JALAN LAKSAMANA,TAMAN JUBILEE,30300 IPOH, PERAK
# 4         JALAN LAKSAMANA,TAMAN JUBILEE,30300 IPOH, PERAK
# ...                                                   ...
# 14565769             217,218,219 & 220,JALAN MEDAN MEWAH,
# 14565770             217,218,219 & 220,JALAN MEDAN MEWAH,
# 14565771             217,218,219 & 220,JALAN MEDAN MEWAH,
# 14565772             217,218,219 & 220,JALAN MEDAN MEWAH,
# 14565773             217,218,219 & 220,JALAN MEDAN MEWAH,
#
#                       premise_type   state district  \
# 0                     Pasar Basah    Perak    Kinta
# 1                     Pasar Basah    Perak    Kinta
# 2                     Pasar Basah    Perak    Kinta
# 3                     Pasar Basah    Perak    Kinta
# 4                     Pasar Basah    Perak    Kinta
# ...                            ...     ...      ...
# 14565769  Pasar Raya / Supermarket  Pahang   Rompin
# 14565770  Pasar Raya / Supermarket  Pahang   Rompin
# 14565771  Pasar Raya / Supermarket  Pahang   Rompin
# 14565772  Pasar Raya / Supermarket  Pahang   Rompin
# 14565773  Pasar Raya / Supermarket  Pahang   Rompin
#
#                                                        item      unit  \
# 0                                    AYAM BERSIH - STANDARD       1kg
# 1         DAGING KAMBING BEBIRI IMPORT BERTULANG (MUTTON...       1kg
# 2                 DAGING KERBAU IMPORT (INDIA) * (TOP SIDE)       1kg
# 3                                               BETIK BIASA       1kg
# 4                                           PISANG BERANGAN       1kg
# ...                                                     ...       ...
# 14565769                        MINYAK MASAK TULEN CAP SAJI      2 kg
# 14565770                        MINYAK MASAK TULEN CAP SAJI      5 kg
# 14565771                        MINYAK MASAK TULEN CAP ALIF      2 kg
# 14565772                               KACANG SOYA (IMPORT)       1kg
# 14565773                          TEMPE (BUNGKUSAN PLASTIK)  sekeping
#
#                    item_group     item_category
# 0              BARANGAN SEGAR              AYAM
# 1              BARANGAN SEGAR            DAGING
# 2              BARANGAN SEGAR            DAGING
# 3              BARANGAN SEGAR       BUAH-BUAHAN
# 4              BARANGAN SEGAR       BUAH-BUAHAN
# ...                       ...               ...
# 14565769  BARANGAN BERBUNGKUS  MINYAK DAN LEMAK
# 14565770  BARANGAN BERBUNGKUS  MINYAK DAN LEMAK
# 14565771  BARANGAN BERBUNGKUS  MINYAK DAN LEMAK
# 14565772      BARANGAN KERING            KACANG
# 14565773       BARANGAN SEGAR   TAUHU DAN TEMPE
#
# [14565774 rows x 13 columns]

# %%
df_reconstructed = df_combine[["date", "premise_type", "district","state","item","item_category","price"]]
df_reconstructed.head()
# Out:
#          date  premise_type district  state  \
# 0  2023-01-01  Pasar Basah     Kinta  Perak
# 1  2023-01-01  Pasar Basah     Kinta  Perak
# 2  2023-01-01  Pasar Basah     Kinta  Perak
# 3  2023-01-01  Pasar Basah     Kinta  Perak
# 4  2023-01-01  Pasar Basah     Kinta  Perak
#
#                                                 item item_category  price
# 0                             AYAM BERSIH - STANDARD          AYAM    9.4
# 1  DAGING KAMBING BEBIRI IMPORT BERTULANG (MUTTON...        DAGING   36.0
# 2          DAGING KERBAU IMPORT (INDIA) * (TOP SIDE)        DAGING   24.0
# 3                                        BETIK BIASA   BUAH-BUAHAN    4.5
# 4                                    PISANG BERANGAN   BUAH-BUAHAN    5.5
