# %% [markdown]
# <a href="https://colab.research.google.com/github/matyi101/price_catcher/blob/main/price_catcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
path = "/content/drive/MyDrive/Colab Notebooks/price_catcher/"

from google.colab import data_table
data_table.enable_dataframe_formatter()
# Out:
# Mounted at /content/drive/

# %%
import os
import pandas as pd
import glob

import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams["figure.figsize"] = (8,4)
plt.rcParams["figure.dpi"] = 160
plt.rcParams["axes.grid"] = True

# %%
premise = pd.read_csv('https://storage.googleapis.com/dosm-public-pricecatcher/lookup_premise.csv')
premise
# Out:
#       premise_code                                            premise  \
# 0               -1                                                NaN
# 1                2                                   PASAR BESAR IPOH
# 2                3                                   JUSCO AYER KEROH
# 3                6                  KEDAI RUNCIT TAFAZ MAJU PRESINT 9
# 4                7                   KEDAI RUNCIT SYAZ MAJU PRESINT 9
# ...            ...                                                ...
# 2689         20882  TARGET GRAND SUPERMARKET (PERDANA) KLUANG PARK...
# 2690         20883                    PASARAYA JAYA GROCER SEKSYEN 14
# 2691         20884                        NUTRIBEST FRESHMART SDN BHD
# 2692         20886                         PASAR AWAM TAMAN KOTA JAYA
# 2693         20888                          BS FRESHMART MUADZAM SHAH
#
#                                                 address  \
# 0                                                     ,
# 1       JALAN LAKSAMANA,TAMAN JUBILEE,30300 IPOH, PERAK
# 2     LOT 4991,MUKIM BUKIT BARU,75450 LEBUH AYER KER...
# 3           NO.5, JALAN P9B/1,PRESINT 9,62250 PUTRAJAYA
# 4           NO.5, JALAN P9E/1,PRESINT 9,62250 PUTRAJAYA
# ...                                                 ...
# 2689  JALAN LINGKARAN TENGAH, TAMAN KLUANG PERDANA,8...
# 2690  LOT LG-17, 18, 18A & 19 JAYA SHOPPING CENTER,,...
# 2691  GROUND FLOOR, WISMA WAN SHOPPING COMPLEX,,TABU...
# 2692           JALAN DELIMA,TAMAN KOTA JAYA,KOTA TINGGI
# 2693               217,218,219 & 220,JALAN MEDAN MEWAH,
#
#                   premise_type           state       district
# 0                          NaN             NaN            NaN
# 1                 Pasar Basah            Perak          Kinta
# 2     Pasar Raya / Supermarket          Melaka  Melaka Tengah
# 3                 Kedai Runcit  W.P. Putrajaya   Wp Putrajaya
# 4                 Kedai Runcit  W.P. Putrajaya   Wp Putrajaya
# ...                        ...             ...            ...
# 2689  Pasar Raya / Supermarket           Johor         Kluang
# 2690  Pasar Raya / Supermarket        Selangor  Petaling Jaya
# 2691                Pasar Mini         Sarawak        Kuching
# 2692              Pasar Basah            Johor    Kota Tinggi
# 2693  Pasar Raya / Supermarket          Pahang         Rompin
#
# [2694 rows x 6 columns]

# %%
items = pd.read_csv('https://storage.googleapis.com/dosm-public-pricecatcher/lookup_item.csv')
items
# Out:
#      item_code                                               item      unit  \
# 0           -1                                                NaN       NaN
# 1            1                             AYAM BERSIH - STANDARD       1kg
# 2            2                                AYAM BERSIH - SUPER       1kg
# 3            3                                         AYAM HIDUP       1kg
# 4            9  DAGING KAMBING BEBIRI IMPORT BERTULANG (MUTTON...       1kg
# ..         ...                                                ...       ...
# 752       2016                         SABUN SERBUK FAB (PERFECT)      680g
# 753       2017                   DYNAMO POWER GEL (PERFECT CLEAN)     2.6kg
# 754       2018                     SABUN PENCUCI SUNLIGHT (LEMON)     900ml
# 755       2019      NESCAFE 3 IN 1 ORIGINAL (AROMATIC & BALANCED)  25 x 18g
# 756       2020              YOGURT LACTEL (FAT FREE) (STRAWBERRY)      130g
#
#             item_group        item_category
# 0                  NaN                  NaN
# 1       BARANGAN SEGAR                 AYAM
# 2       BARANGAN SEGAR                 AYAM
# 3       BARANGAN SEGAR                 AYAM
# 4       BARANGAN SEGAR               DAGING
# ..                 ...                  ...
# 752  PRODUK KEBERSIHAN      PENJAGAAN RUMAH
# 753  PRODUK KEBERSIHAN      PENJAGAAN RUMAH
# 754  PRODUK KEBERSIHAN      PENJAGAAN RUMAH
# 755            MINUMAN  BAHAN-BAHAN MINUMAN
# 756            MINUMAN       TERSEDIA MINUM
#
# [757 rows x 5 columns]

# %%
# Define the directory path where the data are located
directory_path = "/content/drive/MyDrive/Colab Notebooks/price_catcher/data/"

# Use glob to get a list of file names that match a pattern
file_names = glob.glob(directory_path + "*.csv")

# Create an empty list to store the data frames
data_frames = []

# Loop through the file names and read each file as a data frame
for file in file_names:
    # Read the file using pandas read_csv function
    df = pd.read_csv(file)
    # Append the data frame to the list
    data_frames.append(df)

# Use pandas concat function to combine the data frames into one
combined_df = pd.concat(data_frames, ignore_index=True)

# Print the combined data frame
print(combined_df)
# Out:
#                 date  premise_code  item_code  price
# 0         2022-01-01             2          1   9.10
# 1         2022-01-01             2          9  36.00
# 2         2022-01-01             2         14  24.00
# 3         2022-01-01             2         16   4.30
# 4         2022-01-01             2         18   4.50
# ...              ...           ...        ...    ...
# 41969752  2023-07-06         20888       1938  13.30
# 41969753  2023-07-06         20888       1939  30.90
# 41969754  2023-07-06         20888       1941  13.30
# 41969755  2023-07-06         20888       1944   5.99
# 41969756  2023-07-06         20888       1946   1.10
#
# [41969757 rows x 4 columns]

# %%
combined_df
# Out:
# Warning: total number of rows (41969757) exceeds max_rows (20000). Falling back to pandas display.
#                 date  premise_code  item_code  price
# 0         2022-01-01             2          1   9.10
# 1         2022-01-01             2          9  36.00
# 2         2022-01-01             2         14  24.00
# 3         2022-01-01             2         16   4.30
# 4         2022-01-01             2         18   4.50
# ...              ...           ...        ...    ...
# 41969752  2023-07-06         20888       1938  13.30
# 41969753  2023-07-06         20888       1939  30.90
# 41969754  2023-07-06         20888       1941  13.30
# 41969755  2023-07-06         20888       1944   5.99
# 41969756  2023-07-06         20888       1946   1.10
#
# [41969757 rows x 4 columns]
